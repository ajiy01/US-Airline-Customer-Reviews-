# %%
import pandas as pd
import matplotlib.pyplot as plt

#df = pd.read_csv('UA_Reviews_Clean.CSV')
#df = pd.read_csv('AA_Reviews_Clean.CSV')
#df = pd.read_csv('SW_Reviews_Clean.CSV')
#df = pd.read_csv('Delta_Reviews_Clean.CSV')
#df = pd.read_csv('Alaska_Reviews_Clean.CSV')

# Remove rows where the value in 'column_name' does not contain the error
df = df[~df['sentiment'].str.contains('Error', na=False)]

# Convert 'Date Flown' to datetime format
df['Date Flown'] = pd.to_datetime(df['Date Flown'], format='%B %Y')

# Filter records where 'Date Flown' values are between 2020 and 2024
df = df[(df['Date Flown'].dt.year >= 2020) & (df['Date Flown'].dt.year <= 2024)]

# Group data by month and sentiment, and count occurrences
grouped = df.groupby([df['Date Flown'].dt.strftime('%B %Y'), 'sentiment']).size().unstack(fill_value=0)

# Convert index to datetime and sort
grouped.index = pd.to_datetime(grouped.index, format='%B %Y')
grouped = grouped.sort_index()

# Plot
plt.figure(figsize=(12, 6))

# Plot lines with specified colors for each sentiment
grouped.plot(kind='line', marker='o', linewidth=2, color=['red', 'green', 'gray'])

# Custom legend
plt.legend(['Negative', 'Positive', 'Neutral'], title='Sentiment')

plt.title('Alaska Airlines Count of Sentiments Over Time')
plt.xlabel('Year')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

#df = pd.read_csv('UA_Reviews_Clean.CSV')
#df = pd.read_csv('AA_Reviews_Clean.CSV')
#df = pd.read_csv('SW_Reviews_Clean.CSV')
#df = pd.read_csv('Delta_Reviews_Clean.CSV')
#df = pd.read_csv('Alaska_Reviews_Clean.CSV')

# Remove rows where the value in 'column_name' does not contain the error
df = df[~df['sentiment'].str.contains('Error', na=False)]

# Group data by class and sentiment, and count occurrences
grouped = df.groupby(['Seat Type', 'sentiment']).size().unstack(fill_value=0)

# Plot
plt.figure(figsize=(10, 6))

# Plot bars with specified colors for each sentiment
grouped.plot(kind='bar', stacked=False, color=['red', 'green', 'gray'])

# Custom legend
plt.legend(['Negative', 'Positive', 'Neutral'], title='Sentiment')

plt.title('Delta Airlines Sentiments by Class')
plt.xlabel('Class')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt


#df = pd.read_csv('UA_Reviews_Clean.CSV')
#df = pd.read_csv('AA_Reviews_Clean.CSV')
#df = pd.read_csv('SW_Reviews_Clean.CSV')
#df = pd.read_csv('Delta_Reviews_Clean.CSV')
#df = pd.read_csv('Alaska_Reviews_Clean.CSV')

# Remove rows where the value in 'sentiment' contains 'Error'
df = df[~df['sentiment'].str.contains('Error', na=False)]

# Count the occurrences of each type of traveller
traveller_counts = df['Type Of Traveller'].value_counts()

# Plot a pie chart
plt.figure(figsize=(8, 8))
plt.pie(traveller_counts, labels=traveller_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Ratio of Type of Traveller')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle
plt.show()

# %%
import pandas as pd

#df = pd.read_csv('UA_Reviews_Clean.CSV')
#df = pd.read_csv('AA_Reviews_Clean.CSV')
#df = pd.read_csv('SW_Reviews_Clean.CSV')
#df = pd.read_csv('Delta_Reviews_Clean.CSV')
#df = pd.read_csv('Alaska_Reviews_Clean.CSV')

def extract_first_part(review):
    if '|' in review:
        return review.split('|')[0].strip()
    else:
        return None

# Example usage:
# Assume df is your DataFrame with a 'Review' column
# Apply the function to the 'Review' column to create a new column 'First Part'
df['Verification'] = df['Reviews'].apply(extract_first_part)
df

# %%
import pandas as pd




plt.figure(figsize=(8, 6))
df['Verification'].value_counts()[:3].plot(kind='bar', color=['green', 'red', 'gray'])
plt.title('Distribution of Verification Status')
plt.xlabel('Verification Status')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
